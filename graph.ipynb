# %% [markdown]
# # Plot a graph

# %%
# !Ls
# Out:
# Analysis.ipynb logs           pic

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Import the dataframe of training's result for each optimizers

# %%
adam = pd.read_csv('logs/training_Adam.log')
adagrad = pd.read_csv('logs/training_Adagrad.log')
SGD = pd.read_csv('logs/training_SGD.log')
adadelta = pd.read_csv('logs/training_Adadelta.log')
adamax= pd.read_csv('logs/training_Adamax.log')
adam
# Out:
#      epoch  accuracy      loss  val_accuracy  val_loss
# 0        0  0.449533  1.895102      0.503767  1.382570
# 1        1  0.512858  1.337520      0.540400  1.253478
# 2        2  0.536875  1.267973      0.567533  1.197872
# 3        3  0.549842  1.236586      0.554933  1.223830
# 4        4  0.559608  1.215383      0.582133  1.159044
# ..     ...       ...       ...           ...       ...
# 195    195  0.680342  0.908499      0.671967  0.927805
# 196    196  0.680158  0.909181      0.678567  0.916586
# 197    197  0.680417  0.908363      0.676967  0.911908
# 198    198  0.680967  0.905820      0.679467  0.918555
# 199    199  0.681550  0.906051      0.679033  0.915710
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Select a style available from Matplotlib

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-poster')
plt.style.use('seaborn-darkgrid')
#sns.set_theme()

# %% [markdown]
# ## Plot a validation accuracy and loss between each optimizer

# %%
fig , (ax0,ax1) = plt.subplots(nrows=1,ncols=2,figsize=(15,8))

# add data to ax0


ax0.plot(adam['val_accuracy'],label='Adam')
ax0.plot(adagrad['val_accuracy'],label='Adagrad')
ax0.plot(SGD['val_accuracy'],label='SGD')
ax0.plot(adamax['val_accuracy'],label='Adamax')
#ax0.plot(adadelta['val_accuracy'],label='adadelta')
# customize ax0 
ax0.set_yticks(np.arange(0.2,1
                         ,0.03))
ax0.set_title(label='Accuracy',fontsize=40)
ax0.set_xlabel(xlabel='Number of Epochs',fontsize=40)
ax0.set_ylabel(ylabel='val_accuracy',fontsize=40)
ax0.set_ylim([0.41,0.69])
ax0.legend(prop={"size":25});


ax1.plot(adam['val_loss'],label='Adam')
ax1.plot(adagrad['val_loss'],label='Adagrad')
ax1.plot(SGD['val_loss'],label='SGD')
ax1.plot(adamax['val_loss'],label='Adamax')
#ax1.plot(adadelta['val_loss'],label='adadelta')
# customize ax0 

ax1.set_title(label='Loss',fontsize=40)
ax1.set_xlabel(xlabel='Number of Epochs',fontsize=40)
ax1.set_ylabel(ylabel='val_loss',fontsize=40)
ax1.set_yticks(np.arange(.8,2.7,0.15))
ax1.legend(prop={"size":25});
fig.suptitle('Testing with different optimizer ',fontsize=50,fontweight='bold');
fig.tight_layout()

# %% [markdown]
# ## Plot the learning curve of overffitng model

# %%
overfitting= pd.read_csv('logs/training_Overfitting.log')

# %%
overfitting.head()
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.430008  2.304967      0.469700  1.811243
# 1      1  0.494633  1.591880      0.529800  1.388960
# 2      2  0.523283  1.363724      0.542133  1.272449
# 3      3  0.548083  1.264926      0.554133  1.224920
# 4      4  0.566483  1.203682      0.588933  1.147579

# %%
fig , ax = plt.subplots(figsize=(15,10))

ax.plot(overfitting['accuracy'],label='Training')
ax.plot(overfitting['val_accuracy'],label='Validation')

ax.set_xlabel(xlabel='Number of Epochs',fontsize=40)
ax.set_ylabel(ylabel='Accuracy',fontsize=40)
ax.set_ylabel('Accuracy')
ax.text(127, 0.75, '     Overfitting \n (High Variance)', fontsize = 28,fontweight='bold')
  
ax.errorbar(x=[125,125],y=[0.62,0.93],linestyle='--',color='r',marker='o')
ax.legend(prop={"size":25});
fig.suptitle('Overfitting Model',fontsize=50,fontweight='bold');

# %% [markdown]
# ## Plot the learning and error curve of model using Adamax optimizer

# %%
adamax
# Out:
#      epoch  accuracy      loss  val_accuracy  val_loss
# 0        0  0.414842  2.339161      0.493100  1.740497
# 1        1  0.483492  1.617869      0.522933  1.392448
# 2        2  0.515425  1.388040      0.545600  1.286782
# 3        3  0.536617  1.296562      0.563800  1.229552
# 4        4  0.550917  1.239755      0.577133  1.187185
# ..     ...       ...       ...           ...       ...
# 195    195  0.680792  0.890932      0.671633  0.913591
# 196    196  0.682833  0.885839      0.679100  0.893971
# 197    197  0.681800  0.885931      0.669400  0.926470
# 198    198  0.683217  0.885590      0.675300  0.904174
# 199    199  0.682600  0.885452      0.678267  0.893600
#
# [200 rows x 5 columns]

# %%
fig , (ax0,ax1) = plt.subplots(nrows=1,ncols=2,figsize=(18,6))


ax0.plot(adamax_final['accuracy'],label='Training')
ax0.plot(adamax_final['val_accuracy'],label='Validation')


ax0.set_yticks(np.arange(0.2,1
                        ,0.03))
ax0.set_title(label='Accuracy',fontsize=40)
ax0.set_xlabel(xlabel='Number of Epochs',fontsize=40)
ax0.set_ylabel(ylabel='accuracy',fontsize=40)
ax0.set_ylim([0.41,0.69])
ax0.legend(prop={"size":25});


ax1.plot(adamax_final['loss'],label='Training')
ax1.plot(adamax_final['val_loss'],label='Validation')
ax1.set_title(label='Loss',fontsize=40)
ax1.set_xlabel(xlabel='Number of Epochs',fontsize=40)
ax1.set_ylabel(ylabel='loss',fontsize=40)
ax1.set_yticks(np.arange(.8,2.7,0.15))
ax1.legend(prop={"size":25});
fig.suptitle('Adamax Learning and Error Curve',fontsize=50,fontweight='bold');
fig.tight_layout()
